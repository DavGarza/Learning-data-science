# %% [markdown]
# # Basic Probability

# %% [markdown]
# ## I. Fundamentals of Probability
#
# Types of probability

# %% [markdown]
# ### I.I Marginal Probability
#
# Out of a subset of a collection of random variables it gives the probability of a value of the variable in the subset without reference to the values of the other variables.
#
# or
#
# is the probability of an event irrespective of the outcome of another variable
#
# ***P(A) or P(B)***.
#
# Example

# %% [markdown]
# Consider the next situation:
#
# During 18 days, there was a recording where everyday if in the morning was clody,and in the afternoon it rained, and the next table represt the recording

# %%
import pandas as pd
import seaborn as sns
##Creating a pandas dataframe

examples = {
    "Cloudy":[7,2],
    "Not Cloudy":[3,6]
}

examples = pd.DataFrame(examples, index=["Rain","Not Rain"])

example = {
    "Cloudy":[7,2,9],
    "Not Cloudy":[3,6,9],
    "Total":[10,8,18]
}

example = pd.DataFrame(example, index=["Rain","Not Rain","Total"])

example = pd.DataFrame(example, index=["Rain","Not Rain","Total"])

ax = sns.heatmap(examples, annot=True)

# %% [markdown]
# ### I.II Join Probability
#
# Probability of two events ocurring at the same time
#
# ***P(A) and P(B)***.
#
#
# Consider the example above

# %%
import pandas as pd
import seaborn as sns
##Creating a pandas dataframe

examples = {
    "Cloudy":[38,11],
    "Not Cloudy":[16,33]
}

examples = pd.DataFrame(examples, index=["Rain","Not Rain"])

example = pd.DataFrame(example, index=["Rain","Not Rain","Total"])

ax = sns.heatmap(examples, annot= True)

# %% [markdown]
# ### I.III Conditional Probability
#
# Probability of an event ocurring, given that another one has already ocurred
#
# ***P(A|B)***
#
# *Probability of B happening, if a already happend*

# %% [markdown]
# ## II. Distribution of Probability

# %% [markdown]
# ### II.I Continious Probability Distribution

# %% [markdown]
# A probability distribution is a statistical function that describes all the possible values and likelihoods that a random variable can take within a given range.
#
# Reference : https://www.investopedia.com/terms/p/probabilitydistribution.asp#:~:text=A%20probability%20distribution%20is%20a,
# take%20within%20a%20given%20range.
#
# ***P(x ≥ 0)***
#
# Given P, what is the probability of x ≥ 0

# %%
# Importing libraries
import numpy as np
import matplotlib.pyplot as plt
  
# A custom function to calculate
# probability distribution function
def pdf(x):
    mean = np.mean(x)
    std = np.std(x)
    y_out = 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2))
    return y_out
  
# To generate an array of x-values
x = np.arange(-2, 2, 0.1)
  
# To generate an array of 
# y-values using corresponding x-values
y = pdf(x)
  
# To fill in values under the bell-curve
x_fill = np.arange(-2, 2, 0.1)
y_fill = pdf(x_fill)
  
# Plotting the bell-shaped curve
plt.style.use('seaborn')
plt.figure(figsize = (6, 6))
plt.plot(x, y, color = 'black',
         linestyle = 'dashed')
  
plt.scatter(x, y, marker = 'o',
            s = 25, color = 'red')
  
plt.fill_between(x_fill, y_fill, 0,
                 alpha = 0.3, color = 'blue', where= x >= 0)
plt.show()

# %% [markdown]
# ### II.II Discrete Probability Distribution or Bernoulli(Binomial) Probability Distribution

# %% [markdown]
# A frequency distribution of the possible number of successful outcomes in a given number of trials in each of which there is the same boolean discrete probability of success.
#
# Given *n* as the number of repetitions and *p* the probability, and *k* the exact succeses in *n* trials
#
# $$
#   \ (n k) \, = \frac{\ n!}{k!(n-k)!}
# $$
#
# Consider the next situation
#
# There is 3 coins, and the coins are thrown
# What is the probability of getting 2 heads
#
# $$
#   \ (3,2) \, = \frac{\ 3}{2!(3-2)!}
# $$

# %% [markdown]
# The formula above considers a fair probability between the 2 possible values, but sometimes it isn´t, so the formula for when it insn´t fair is
#
# $$
# P(k, n; p) = {n \choose k} p^k (1-p)^{n-k} = \frac{n!}{k!(n-k)!}p^k (1-p)^{n-k}
# $$
#
# And we can make transform it into a pyhton function like the next one

# %%
import numpy as np
from numpy.random import binomial
from scipy.stats import binom
from math import factorial
import matplotlib.pyplot as plt

def binomial(k, n, p):
  return factorial(n)/(factorial(k)*(factorial(n-k)))*pow(p,k)*pow(1-p, n-k)

## We can try the function with the same example above
binomial(2,3, 0.5)
# Out:
# 0.375

# %%
## And we can use the scipy library in the next way

dist = binom(3, 0.5)
dist.pmf(2)
# Out:
# 0.375

# %% [markdown]
# ### II.III Normal Distribution
#
# Is a type of continuous probability distribution for a real-valued random variable. Often called "bell shaped" (be careful with this concept because many others distributions have a bell shaped)
#
# Source: https://en.wikipedia.org/wiki/Normal_distribution#Definitions
#
# **Formula**
#
# $$P(X) = \frac{1}{\sigma \sqrt{2 \pi}} \exp{\left[-\frac{1}{2}\left(\frac{X-\mu}{\sigma} \right)^2 \right]}$$

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
#Normal distribution formula with a python function

def gaussian(x, mu, sigma):
  return 1/(sigma*np.sqrt(2*np.pi))*np.exp(-0.5*pow((x-mu)/sigma,2))

x = np.linspace(-10,10,20)
med = np.median(x)
stdev = np.std(x)

y = gaussian(x,med,stdev)

plt.plot(x, y)

# %%
#We can also use the scipy library with the "gaussian function"

# %% [markdown]
# ## III. MLE (Maximun Likelihood Estimate)
